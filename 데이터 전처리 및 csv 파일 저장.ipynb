# %%
import pandas as pd
import numpy as np

# %%
# 기온 데이터 읽어오기
temp_df = pd.read_csv('data/기온.csv', skiprows=7, engine='python')

# %%
temp_df.shape
# Out:
# (3712, 5)

# %%
temp_df.head()
# Out:
#            날짜  지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  2010-01-01  전국     -4.9    -11.0      0.9
# 1  2010-01-02  전국     -0.1     -5.5      5.5
# 2  2010-01-03  전국     -2.9     -6.9      1.4
# 3  2010-01-04  전국     -1.8     -5.1      2.2
# 4  2010-01-05  전국     -5.2     -8.7     -1.8

# %%
temp_df.drop('지점', axis=1, inplace=True)
temp_df.head()
# Out:
#            날짜  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  2010-01-01     -4.9    -11.0      0.9
# 1  2010-01-02     -0.1     -5.5      5.5
# 2  2010-01-03     -2.9     -6.9      1.4
# 3  2010-01-04     -1.8     -5.1      2.2
# 4  2010-01-05     -5.2     -8.7     -1.8

# %%
temp_df.dtypes
# Out:
# 날짜          object
# 평균기온(℃)    float64
# 최저기온(℃)    float64
# 최고기온(℃)    float64
# dtype: object

# %%
temp_df.isnull().sum()
# Out:
# 날짜         0
# 평균기온(℃)    0
# 최저기온(℃)    0
# 최고기온(℃)    0
# dtype: int64

# %%
temp_df.describe()
# Out:
#            평균기온(℃)      최저기온(℃)      최고기온(℃)
# count  3712.000000  3712.000000  3712.000000
# mean     12.892861     8.171821    18.320205
# std       9.788293    10.211749     9.795578
# min     -10.800000   -14.800000    -7.400000
# 25%       4.200000    -0.700000     9.700000
# 50%      13.600000     8.400000    19.800000
# 75%      21.700000    17.400000    27.000000
# max      30.300000    25.900000    36.600000

# %%
# 강수량 데이터 읽어오기
rainfall_df = pd.read_csv('data/강수량.csv', skiprows=7, engine='python')

# %%
rainfall_df.shape
# Out:
# (3712, 3)

# %%
rainfall_df.head()
# Out:
#            날짜  지점  강수량(mm)
# 0  2010-01-01  전국      0.0
# 1  2010-01-02  전국      0.8
# 2  2010-01-03  전국      0.0
# 3  2010-01-04  전국      5.9
# 4  2010-01-05  전국      0.7

# %%
rainfall_df.drop(['날짜', '지점'], axis=1, inplace=True)
rainfall_df.head()
# Out:
#    강수량(mm)
# 0      0.0
# 1      0.8
# 2      0.0
# 3      5.9
# 4      0.7

# %%
rainfall_df.dtypes
# Out:
# 강수량(mm)    float64
# dtype: object

# %%
rainfall_df.isnull().sum()
# Out:
# 강수량(mm)    0
# dtype: int64

# %%
rainfall_df.describe()
# Out:
#            강수량(mm)
# count  3712.000000
# mean      3.442457
# std       8.745856
# min       0.000000
# 25%       0.000000
# 50%       0.100000
# 75%       2.100000
# max     106.300000

# %%
# 기온, 강수량 데이터 합치기
temp_rainfall_df = pd.concat([temp_df, rainfall_df], axis=1)
temp_rainfall_df.columns = ['date', 'avgTemp', 'minTemp', 'maxTemp', 'rainfall']
temp_rainfall_df.shape
# Out:
# (3712, 5)

# %%
temp_rainfall_df.isnull().sum()
# Out:
# date        0
# avgTemp     0
# minTemp     0
# maxTemp     0
# rainfall    0
# dtype: int64

# %%
temp_rainfall_df.head()
# Out:
#          date  avgTemp  minTemp  maxTemp  rainfall
# 0  2010-01-01     -4.9    -11.0      0.9       0.0
# 1  2010-01-02     -0.1     -5.5      5.5       0.8
# 2  2010-01-03     -2.9     -6.9      1.4       0.0
# 3  2010-01-04     -1.8     -5.1      2.2       5.9
# 4  2010-01-05     -5.2     -8.7     -1.8       0.7

# %%
temp_rainfall_df.tail()
# Out:
#             date  avgTemp  minTemp  maxTemp  rainfall
# 3707  2020-02-25      7.5      5.7     10.0      28.1
# 3708  2020-02-26      7.0      3.1     11.9       1.5
# 3709  2020-02-27      5.3      1.2     10.4       0.1
# 3710  2020-02-28      4.5      1.7      6.8       2.7
# 3711  2020-02-29      6.7      2.7     12.1       0.0

# %%
temp_rainfall_df.dtypes
# Out:
# date         object
# avgTemp     float64
# minTemp     float64
# maxTemp     float64
# rainfall    float64
# dtype: object

# %%
# 평균 배추가격 데이터 읽어오기
# 여러 파일로 나눠진 배추가격 데이터를 반복문으로 읽어와서 하나의 df로 합치기
fileName_0 = [str(tmp) for tmp in range(2010, 2021)]    # 2010 ~ 2020
fileName_1 = [str(tmp) for tmp in range(1, 5)]    # 1 ~ 4

concated_df = pd.DataFrame(data={}, columns=['date', 'price'])

for tmp0 in fileName_0:
    for tmp1 in fileName_1:
        
        # 파일 읽기
        ori_df = pd.read_excel('data/' + tmp0 + '-' + tmp1 + '.xlsx')
        
        # 불필요한 열 제거
        ori_df.drop(ori_df.columns[0:3], axis=1, inplace=True)
        
        # 불필요한 행 제거
        ori_df.drop(ori_df.index[1:], inplace=True)
        
        # 행과 열을 바꾸고 price 컬럼명 지정
        ori_df = ori_df.T
        ori_df.columns = ['price']
        
        # index를 가져와서 date타입을 str로 형식에 맞게 바꾸고 리스트에 넣음
        index_list = ori_df.index
        index_list = [str(index).split(' ')[0].replace('2020', tmp0) for index in index_list]
        
        # 만든 리스트를 date컬럼으로 지정한 뒤 컬럼명 순서 재배치
        ori_df['date'] = index_list
        ori_df = ori_df[['date', 'price']]
        
        # 기존 데이터와 새로 읽은 파일의 데이터를 합침
        concated_df = pd.concat([concated_df, ori_df])
        
        # log
        print('읽은파일: ' + tmp0 + '-' + tmp1 + '.xlsx')
        print(ori_df.head())
        print(ori_df.isnull().sum())
        print('-' * 50)
        
        if tmp0 == '2020':
            break
        
concated_df.reset_index(drop=True, inplace=True)
concated_df.shape
# Out:
# 읽은파일: 2010-1.xlsx
#                            date  price
# 2020-01-04 00:00:00  2010-01-04  2,123
# 2020-01-05 00:00:00  2010-01-05  2,209
# 2020-01-06 00:00:00  2010-01-06  2,209
# 2020-01-07 00:00:00  2010-01-07  2,266
# 2020-01-08 00:00:00  2010-01-08  2,266
# date     0
# price    0
# dtype: int64
# --------------------------------------------------
# 읽은파일: 
# date     0
# price    0
# dtype: int64
# --------------------------------------------------
# 읽은파일: 2018-3.xlsx
#                            date  price
# 2020-07-02 00:00:00  2018-07-02  2,986
# 2020-07-03 00:00:00  2018-07-03  2,990
# 2020-07-04 00:00:00  2018-07-04  3,004
# 2020-07-05 00:00:00  2018-07-05  3,060
# 2020-07-06 00:00:00  2018-07-06  3,015
# date     0
# price    0
# dtype: int64
# --------------------------------------------------
# 읽은파일: 2018-4.xlsx
#                            date  price
# 2020-10-01 00:00:00  2018-10-01  5,321
# 2020-10-02 00:00:00  2018-10-02  4,897
# 2020-10-04 00:00:00  2018-10-04  4,559
# 2020-10-05 00:00:00  2018-10-05  4,400
# 2020-10-08 00:00:00  2018-10-08  4,464
# date     0
# price    0
# dtype: int64
# --------------------------------------------------
# 읽은파일: 2019-1.xlsx
#                            date  price
# 2020-01-02 00:00:00  2019-01-02  2,722
# 2020-01-03 00:00:00  2019-01-03  2,709
# 2020-01-04 00:00:00  2019-01-04  2,709
# 2020-01-07 00:00:00  2019-01-07  2,748
# 2020-01-08 00:00:00  2019-01-08  2,772
# date     0
# price    0
# dtype: int64
# --------------------------------------------------
# 읽은파일: 2019-2.xlsx
#                            date  price
# 2020-04-01 00:00:00  2019-04-01  2,201
# 2020-04-02 00:00:00  2019-04-02  2,201
# 2020-04-03 00:00:00  2019-04-03  2,201
# 2020-04-04 00:00:00  2019-04-04  2,231
# 2020-04-05 00:00:00  2019-04-05  2,246
# date     0
# price    0
# dtype: int64
# --------------------------------------------------
# 읽은파일: 2019-3.xlsx
#                            date  price
# 2020-07-01 00:00:00  2019-07-01  3,031
# 2020-07-02 00:00:00  2019-07-02  3,038
# 2020-07-03 00:00:00  2019-07-03  3,027
# 2020-07-04 00:00:00  2019-07-04  3,077
# 2020-07-05 00:00:00  2019-07-05  3,062
# date     0
# price    0
# dtype: int64
# --------------------------------------------------
# 읽은파일: 2019-4.xlsx
#                            date  price
# 2020-10-01 00:00:00  2019-10-01  7,177
# 2020-10-02 00:00:00  2019-10-02  7,328
# 2020-10-04 00:00:00  2019-10-04  7,876
# 2020-10-07 00:00:00  2019-10-07  8,004
# 2020-10-08 00:00:00  2019-10-08  7,437
# date     0
# price    0
# dtype: int64
# --------------------------------------------------
# 읽은파일: 2020-1.xlsx
#                            date  price
# 2020-01-02 00:00:00  2020-01-02  4,584
# 2020-01-03 00:00:00  2020-01-03  4,591
# 2020-01-06 00:00:00  2020-01-06  4,613
# 2020-01-07 00:00:00  2020-01-07  4,627
# 2020-01-08 00:00:00  2020-01-08  4,627
# date     0
# price    0
# dtype: int64
# --------------------------------------------------
# (2507, 2)

# %%
concated_df.isnull().sum()
# Out:
# date     0
# price    0
# dtype: int64

# %%
# 기온, 강수량 데이터와 배추가격 데이터 합치기(최종)
merged_df = pd.merge(temp_rainfall_df, concated_df, how='outer')
merged_df.shape
# Out:
# (3712, 6)

# %%
merged_df.isnull().sum()
# Out:
# date           0
# avgTemp        0
# minTemp        0
# maxTemp        0
# rainfall       0
# price       1205
# dtype: int64

# %%
merged_df.head()
# Out:
#          date  avgTemp  minTemp  maxTemp  rainfall  price
# 0  2010-01-01     -4.9    -11.0      0.9       0.0    NaN
# 1  2010-01-02     -0.1     -5.5      5.5       0.8    NaN
# 2  2010-01-03     -2.9     -6.9      1.4       0.0    NaN
# 3  2010-01-04     -1.8     -5.1      2.2       5.9  2,123
# 4  2010-01-05     -5.2     -8.7     -1.8       0.7  2,209

# %%
merged_df.tail()
# Out:
#             date  avgTemp  minTemp  maxTemp  rainfall  price
# 3707  2020-02-25      7.5      5.7     10.0      28.1  4,396
# 3708  2020-02-26      7.0      3.1     11.9       1.5  4,296
# 3709  2020-02-27      5.3      1.2     10.4       0.1  4,296
# 3710  2020-02-28      4.5      1.7      6.8       2.7  4,296
# 3711  2020-02-29      6.7      2.7     12.1       0.0    NaN

# %%
# 결측값(주말 배추가격) 채우기 - 해당 주의 금요일 가격으로 채움
fillna_df = merged_df.fillna(method='ffill')
fillna_df.isnull().sum()
# Out:
# date        0
# avgTemp     0
# minTemp     0
# maxTemp     0
# rainfall    0
# price       3
# dtype: int64

# %%
fillna_df.head()
# Out:
#          date  avgTemp  minTemp  maxTemp  rainfall  price
# 0  2010-01-01     -4.9    -11.0      0.9       0.0    NaN
# 1  2010-01-02     -0.1     -5.5      5.5       0.8    NaN
# 2  2010-01-03     -2.9     -6.9      1.4       0.0    NaN
# 3  2010-01-04     -1.8     -5.1      2.2       5.9  2,123
# 4  2010-01-05     -5.2     -8.7     -1.8       0.7  2,209

# %%
# 앞의 3개의 데이터는 임의(1월 4일 가격)의 값으로 채움
fillna_df.iloc[:3].fillna('2,123', inplace=True)

fillna_df.isnull().sum()
# 결측치 완전히 채움
# Out:
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py:4244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs
# date        0
# avgTemp     0
# minTemp     0
# maxTemp     0
# rainfall    0
# price       0
# dtype: int64

# %%
fillna_df.head()
# Out:
#          date  avgTemp  minTemp  maxTemp  rainfall  price
# 0  2010-01-01     -4.9    -11.0      0.9       0.0  2,123
# 1  2010-01-02     -0.1     -5.5      5.5       0.8  2,123
# 2  2010-01-03     -2.9     -6.9      1.4       0.0  2,123
# 3  2010-01-04     -1.8     -5.1      2.2       5.9  2,123
# 4  2010-01-05     -5.2     -8.7     -1.8       0.7  2,209

# %%
fillna_df.dtypes
# 데이터 타입을 확인해보니 맞지 않는 부분이 있어서 바꿔줄 필요가 있음
# price -> float
# Out:
# date         object
# avgTemp     float64
# minTemp     float64
# maxTemp     float64
# rainfall    float64
# price        object
# dtype: object

# %%
# price를 float타입으로 바꿈
fillna_df['price'] = fillna_df['price'].apply(lambda x: x.replace(',', '')).astype('float')
fillna_df.head()
# Out:
#          date  avgTemp  minTemp  maxTemp  rainfall   price
# 0  2010-01-01     -4.9    -11.0      0.9       0.0  2123.0
# 1  2010-01-02     -0.1     -5.5      5.5       0.8  2123.0
# 2  2010-01-03     -2.9     -6.9      1.4       0.0  2123.0
# 3  2010-01-04     -1.8     -5.1      2.2       5.9  2123.0
# 4  2010-01-05     -5.2     -8.7     -1.8       0.7  2209.0

# %%
# 데이터 전처리가 끝났으므로 csv 파일로 저장
fillna_df.to_csv("data/dataset.csv", mode='w', index=False)
